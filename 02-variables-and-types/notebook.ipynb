# %% [markdown]
# # Lesson 02 -- Variables and Types
#
# **Python Bootcamp | Morehouse Supercomputing Facility**
#
# In this notebook you'll practice creating variables, working with different data types, and using arithmetic operators.

# %% [markdown]
# ---
# ## Exercise 1: Create Variables
#
# Create the following variables:
# - `first_name` -- your first name (string)
# - `last_name` -- your last name (string)
# - `age` -- your age (integer)
# - `gpa` -- your GPA (float)
# - `is_student` -- whether you are a student (boolean)
#
# Then print each one.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 2: Check Types
#
# Use `type()` to print the type of each variable you created above.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 3: Arithmetic Practice
#
# Calculate the following and print each result:
# 1. 247 + 389
# 2. 1000 - 273
# 3. 15 * 23
# 4. 100 / 7 (regular division)
# 5. 100 // 7 (floor division)
# 6. 100 % 7 (remainder)
# 7. 2 ** 10 (exponent)

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 4: f-strings
#
# Using the variables from Exercise 1, write a single `print()` statement using an f-string that outputs something like:
#
# ```
# My name is Marcus Johnson. I am 19 years old with a 3.5 GPA.
# ```

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 5: Type Casting
#
# The variable below is a string. Convert it to an integer, add 10 to it, and print the result.

# %%
mystery_number = "42"

# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 6: String Operations
#
# 1. Create two variables: `school` set to `"Morehouse"` and `mascot` set to `"Maroon Tigers"`
# 2. Concatenate them into a single string with a space in between and print it
# 3. Print the length of the combined string
# 4. Print the mascot repeated 3 times

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 7: User Input
#
# Write a program that:
# 1. Asks the user for their name
# 2. Asks the user for their birth year (as a number)
# 3. Calculates their approximate age (2026 minus their birth year)
# 4. Prints a message like: `"Hello, Marcus! You are approximately 21 years old."`

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Challenge: Temperature Converter
#
# Write a program that:
# 1. Asks the user for a temperature in Fahrenheit
# 2. Converts it to Celsius using the formula: `C = (F - 32) * 5/9`
# 3. Prints the result rounded to 1 decimal place
#
# Hint: Use `round(value, 1)` to round.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
#
# **Done!** Save this notebook and submit it to Canvas.

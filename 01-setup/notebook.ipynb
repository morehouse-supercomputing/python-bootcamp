# %% [markdown]
# # Lesson 01 -- Setup and Installation
#
# **Python Bootcamp | Morehouse Supercomputing Facility**
#
# Welcome! This notebook confirms your environment is set up correctly. Run each cell with **Shift + Enter**.

# %% [markdown]
# ---
# ## Exercise 1: Hello, World!
#
# Run the cell below. If you see output, Python is working.

# %%
print("Hello, Python Bootcamp!")

# %% [markdown]
# ---
# ## Exercise 2: Check Your Python Version
#
# This confirms which Python version your venv is using.

# %%
import sys
print(f"Python version: {sys.version}")
print(f"Python location: {sys.executable}")

# %% [markdown]
# ---
# ## Exercise 3: Verify Your Virtual Environment
#
# The Python location above should contain `venv` in the path. That means you're running inside your virtual environment. If it doesn't, go back to the setup guide and activate your venv.
#
# Now let's check that all the bootcamp libraries installed correctly from `requirements.txt`.

# %%
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns
import requests

print(f"NumPy:      {np.__version__}")
print(f"Pandas:     {pd.__version__}")
print(f"Matplotlib: {matplotlib.__version__}")
print(f"Seaborn:    {sns.__version__}")
print(f"Requests:   {requests.__version__}")
print("\nAll libraries installed! You're ready for the bootcamp.")

# %% [markdown]
# ---
# ## Exercise 4: Your First Code
#
# Write a `print()` statement that says your name and your program (ML, SBX, GenAI, or CJ).

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 5: Math in Python
#
# Use Python as a calculator. Write an expression that calculates how many hours are in a year (365 days x 24 hours).

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
#
# **Done!** Save this notebook and submit it to Canvas.
